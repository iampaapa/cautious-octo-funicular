# %% [markdown]
# ### Question Synthesis Engine
#
# This allows me to generate high-quality questions for the students by finetuning a Llama 3 8b model for high-quality question generation. Of course, to me the questions might seem high-quality but in actual fact may not be so I created a simple streamlit application which is in the same folder to conduct a blind test with randomly chosen questions mixed with actual NSMQ questions. After 10 people took the test, we recorded a high accuracy of people marking the synthetic questions for actual questions.

# %% [markdown]
# ---
#
# First we check the GPU version available in the environment and install specific dependencies that are compatible with the detected GPU to prevent version conflicts.

# %%
# %%capture
import torch
major_version, minor_version = torch.cuda.get_device_capability()
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
if major_version >= 8:
    # !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # !pip install --no-deps xformers trl peft accelerate bitsandbytes
pass

# %% [markdown]
# Next we need to prepare to load a range of quantized language models, including the model we want to use - the LLama-3 model with 4-bit quantization.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None
load_in_4bit = True # im using 4bit quantization to reduce memory usage. Can be False.

fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit",
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit",
    "unsloth/llama-3-8b-bnb-4bit",
    "unsloth/llama-3-70b-Instruct-bnb-4bit",
]

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Llama patching release 2024.6
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ---
#
# Next, we integrate LoRA adapters into our model, which allows us to efficiently update just a fraction of the model's parameters, enhancing training speed and reducing computational load.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2024.6 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We are using a combined csv file that contains all the questions that was provided us for the hackathon. I wrote a script to combine the questions from the various years into one file. But the dataset contains only questions from the Fundamental Questions Round so to efficiently simulate questions from the other rounds, I wrote a script to get the transcripts from about 25 NSMQ videos and then I extracted the questions from there.
#
# ---
# Then, we define a system prompt that formats tasks into instructions, inputs, and responses, and apply it to a dataset to prepare our inputs and outputs for the model, with an EOS token to signal completion.

# %% [markdown]
# ### Creating the Combined Dataset
#
# Given the Google Drive folder of NSMQ Questions, we had to create a combined csv file containing all the questions so that we could train our model effectively. I also had to scrape transcripts from past NSMQ contests to get questions from the other rounds to help effectively generate questions from the other rounds.

# %%
import pandas as pd
from google.colab import drive
import gspread
import os

# Mounting Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the root folder containing the NSMQ QUESTIONS directory
root_folder = '/content/drive/MyDrive/Brilla AI Resources'

# %%
def read_excel_files(root_folder):
    data_frames = []

    if not os.path.exists(root_folder):
        print(f"Root folder not found: {root_folder}")
        return data_frames

    print(f"Root folder: {root_folder}")

    for year_folder in os.listdir(root_folder):
        year_folder_path = os.path.join(root_folder, year_folder)
        print(f"Year folder: {year_folder_path}")

        if os.path.isdir(year_folder_path):
            for file in os.listdir(year_folder_path):
                file_path = os.path.join(year_folder_path, file)
                print(f"Found file: {file_path}")

                if file.endswith('.xlsx') or file.endswith('.xls'):
                    print(f"Reading {file_path}")
                    df = pd.read_excel(file_path)
                    data_frames.append(df)

    return data_frames

# Read all Excel files and combine them into a single DataFrame
data_frames = read_excel_files(root_folder)

if data_frames:
    combined_df = pd.concat(data_frames, ignore_index=True)
    # Save the combined DataFrame to a CSV file
    output_path = '/content/drive/My Drive/combined_data.csv'
    combined_df.to_csv(output_path, index=False)
    print(f"Data has been combined and saved to {output_path}")
else:
    print("No data frames to combine.")
# Out:
# Root folder: /content/drive/MyDrive/Brilla AI Resources
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2020
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2020/2020 NSMQ contest 9.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2019
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2019/2019 NSMQ contest 6.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2018
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2018/2018 NSMQ contest 18.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2017
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2017/2017 NSMQ contest 35.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2016
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 24(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 24(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 17(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 17(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 20(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 20(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 21(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 21(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 22(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 22(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 23(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 23(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 2(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 2(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 19(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 19(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 18(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 18(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 25(1).xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 25(1).xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2016/2016 NSMQ contest 15.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2015
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 64.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 64.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 48.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 48.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 44.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 44.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 45.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 45.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 52.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 52.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 49.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 49.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 65.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 65.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 54.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 54.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 53.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 53.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 42.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 42.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 58.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 58.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 63.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 63.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 62.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 62.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 59.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 59.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 55.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 55.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 60.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 60.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 56.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 56.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 43.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 43.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 57.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 57.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 41.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 41.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 66.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 66.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 46.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 46.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 61.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 61.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 47.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 47.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 67.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 67.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 50.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 50.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 51.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 51.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2015/2015 NSMQ contest 10.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2014
# Found file: /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 58.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 58.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 55.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 55.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 43.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2014/2014 NSMQ contest 43.xlsx
# ...
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2013/2013 NSMQ contest 4.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2012
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 23.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 23.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 27.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 27.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 25.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 25.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 24.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 24.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 26.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 26.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2012/2012 NSMQ contest 16.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2009
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 18.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 18.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 15.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 15.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 8.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 21.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 21.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 17.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 17.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 19.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 19.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 22.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 22.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 16.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 16.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 20.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 20.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2009/2009 NSMQ contest 5.xlsx
# Year folder: /content/drive/MyDrive/Brilla AI Resources/2021
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 5.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 5.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 38.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 38.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 3.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 3.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 28.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 28.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 30.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 30.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 39.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 39.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 1.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 1.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 2.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 2.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 34.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 34.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 33.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 33.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 11.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 11.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 35.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 35.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 9.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 9.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 29.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 29.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 10.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 10.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 6.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 6.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 40.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 40.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 12.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 12.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 14.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 14.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 37.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 37.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 4.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 4.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 7.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 7.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 36.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 36.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 32.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 32.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 13.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 13.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 31.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 31.xlsx
# Found file: /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 8.xlsx
# Reading /content/drive/MyDrive/Brilla AI Resources/2021/2021 NSMQ contest 8.xlsx
# Data has been combined and saved to /content/drive/My Drive/combined_data.csv

# %%
# !pip install pytube youtube-transcript-api
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: youtube-transcript-api in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.2.2)
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from pytube import Playlist
from youtube_transcript_api import YouTubeTranscriptApi

# Function to get the transcript of a single video
def get_transcript(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        transcript_text = ''
        for line in transcript_list:
            transcript_text += line['text'] + ' '
        return transcript_text
    except Exception as e:
        print(f"An error occurred for video {video_id}: {str(e)}")
        return None

# Main function to iterate through the playlist and write transcripts to a file
def get_transcripts_from_playlist(playlist_url, output_file):
    playlist = Playlist(playlist_url)
    video_ids = [video.video_id for video in playlist.videos]

    with open(output_file, 'w', encoding='utf-8') as f:
        for video_id in video_ids:
            print(f"Fetching transcript for video ID: {video_id}")
            transcript = get_transcript(video_id)
            if transcript:
                f.write(transcript + '\n\n')
    print(f"Transcripts have been written to {output_file}")

# Example usage
if __name__ == "__main__":
    playlist_url = 'https://youtube.com/playlist?list=PLLbHBxYIftwvrWScPQQKitFVT11-MBUlK&si=f0I9PiaGDvvyeY1y'
    output_file = 'transcripts.txt'

    get_transcripts_from_playlist(playlist_url, output_file)
# Out:
# Fetching transcript for video ID: 3N4tI9aOTVw
# Fetching transcript for video ID: imuvkEb9rmQ
# Fetching transcript for video ID: 9mYYhigVxh8
# Fetching transcript for video ID: UJaocPqJz58
# Fetching transcript for video ID: 0aWI4GWxMJk
# Fetching transcript for video ID: lOr3h3qOr4U
# Fetching transcript for video ID: 19zsntIBkMo
# Fetching transcript for video ID: 1Q9B6Uqgw2U
# Fetching transcript for video ID: G53NMVV59FE
# Fetching transcript for video ID: fE-qVk4HDHA
# Fetching transcript for video ID: K1cBKW2gEZs
# Fetching transcript for video ID: V3dbA4rGrcw
# Fetching transcript for video ID: 2lxLwkGStn0
# Fetching transcript for video ID: 18ntn6Z1Ea8
# Fetching transcript for video ID: OjEIgrBwV7c
# Fetching transcript for video ID: lUfW7RZ9aKA
# Fetching transcript for video ID: l30tHg9tmLA
# Fetching transcript for video ID: 01tSRqMUd3I
# Fetching transcript for video ID: WPuhIZfPO0A
# Fetching transcript for video ID: fIiAyetZnqI
# Fetching transcript for video ID: uH3AP4g9rys
# Fetching transcript for video ID: sf79egmhZmE
# Transcripts have been written to transcripts.txt

# %% [markdown]
# ---
#
# From here, a lot of manual work was done to get the questions from the transcript. The transcript is not perfect and because of this, manual extraction of the questions and formatting them into a cleaner format was needed. Please check the folder that this file is found in. It'll contain the combined + annotated + cleaned dataset named "Question Synth Dataset"

# %%
from datasets import load_dataset
from datasets import Dataset

question_synth_prompt = """You're a highly respected college instructor at one of the most renowed institutions in the world.
You're tasked with setting questions for the renowed National Maths and Science Quiz.
The National Science and Math Quiz is a competition where first year college students compete by solving questions from various fields of STEM (principally Chemistry, Physics, Mathematics and Biology)
As you're a highly respected college instructor in the STEM field, your questions should be as top quality and thought provoking as possible.
If your questions are not as high-quality, someone will die. If your question doesn't obey the input, someone will die.
Based on the input, put in the MAXIMUM effort to generate high stardard and quality questions at the level of a final year college student who is highly speicialized in the specified field can answer.
The questions must not be so easy for even a third year student in the field. The standard should be that high.
Take good note of the input values and produce desired outputs based on the input values.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

csv_file_path = "/content/drive/MyDrive/afried/Question Synth Dataset.csv"  # Update this with your actual file path
df = pd.read_csv(csv_file_path)
dataset = Dataset.from_pandas(df)

EOS_TOKEN = tokenizer.eos_token

def formatting_prompts_func(examples):
    texts = []
    for has_preamble, preamble_text, question, answer, subject, question_type in zip(
        examples["has_preamble"], examples["preamble_text"], examples["question"],
        examples["answer"], examples["subject"], examples["question_type"]
    ):
        # Construct the instruction and input for the new question
        instruction = f"Create a high-quality college level question and answer based on the given subject and question type. Please take a note of the question type. It is TOO TOO IMPORTANT."
        input_text = f"Example:\nHas Preamble: {has_preamble}\nSubject: {subject}\nQuestion Type: {question_type}"
        output_text = f"Preamble Text: {preamble_text}\nQuestion: {question}\nAnswer: {answer}"
        text = question_synth_prompt.format(instruction, input_text, output_text) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# Apply the formatting function to the dataset
dataset = dataset.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/15852 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# At this stage, we're configuring our model's training setup, where we define things like batch size and learning rate, to teach our model effectively with the data we have prepared.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 150, # increase this to make the model learn "better"
        # num_train_epochs=1,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1965: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:269: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:283: UserWarning: You passed a `dataset_num_proc` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:307: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/15852 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 11.033 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 15,852 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 150
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 27:59, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.515300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.552500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.411400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.389400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.313700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.199700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.933600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.543800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.314800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.144100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.828300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.599700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.554200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.363700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.320700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.333700</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.269500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.359000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.356200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.293200</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.441500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.295100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.294000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.330600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.237200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.360600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.246300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.261800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.338600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.290800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.276100</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.204600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.258100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.233300</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.310600</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.235600</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.285500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.240100</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.209500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.325500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.270100</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.243300</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.262600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.393800</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.255200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.271900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.250200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.245000</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.232100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.333800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.289700</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.282600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.182400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.233500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.164700</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.242200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.209100</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.219700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.223300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.166800</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.281300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.331900</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.313400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.234000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.235100</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.316400</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.252000</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.277400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.203400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.272800</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.199600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.200600</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.216100</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.267100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.252100</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.216200</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.237000</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.330700</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.313200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.210500</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.242100</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.221400</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.245300</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.254100</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.342000</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.256100</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.262200</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.212100</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.207700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.275900</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.207200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.344600</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.270600</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.175500</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.242000</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.218400</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.218300</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.276000</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.223100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.284500</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.201700</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.238500</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.317600</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.303100</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.294300</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.192000</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.271600</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.277100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.216400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.228000</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.307700</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.252600</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.243400</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.176200</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.244600</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.290600</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.286500</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.253400</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.262300</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.193800</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.351600</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.206700</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.259300</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.222700</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.315300</td>
#     </tr>
#     <tr>
#       <td>126</t

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 1502.46 seconds used for training.
# 25.04 minutes used for training.
# Peak reserved memory = 11.033 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 74.81 %.
# Peak reserved memory for training % of max memory = 0.0 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model and save our questions to the SQLite file!  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time! The whole idea of this was to make sure that students had enough high-quality questions to practice without having to hit any endpoint or use the copyrighted questions.
#
# The following were the statistics we **aimed** for. Due to time, we were able to generate about 10,600 questions;
#
# **15,600 questions** in total;
# 1. Fundamental Questions (ALL AREAS - Bio, Chem, Math and Physics)
# 2. Riddles
# 3. True and False

# %%
# @title Text Extraction
import re

def extract_info(text):
    # Split the text into blocks based on the "### Input" delimiter
    blocks = text.split("### Input:")

    results = []

    for block in blocks[1:]:  # Skip the first empty block
        # Extract information from each block
        match = re.search(r'Subject: (.*?)\nQuestion Type:', block, re.DOTALL)
        if match:
            subject = match.group(1).strip()
        else:
            subject = ""

        match = re.search(r'Has Preamble: (.*?)\nSubject: (.*?)\nPreamble Text: (.*?)\nQuestion: (.*?)\nAnswer: (.*?)\n', block, re.DOTALL)
        if match:
            has_preamble, _, preamble, question, answer = match.groups()
            if (answer.strip().find("<|begin_of_text|>")) > 0:
              answer = answer.strip()[ : answer.strip().find("<|begin_of_text|>")]
            else:
              answer = answer.strip()

            results.append({
                'has preamble': has_preamble.strip(),
                'subject' : subject,
                'preamble': preamble.strip(),
                'question': question.strip(),
                'answer': answer
            })

    return results


# results = extract_info(test_text)

# for result in results:
#   print(result)

# %%
# @title CSV Operations
import csv

def write_to_csv(preamble, question, answer, subject, path="/content/drive/MyDrive/afried/generatedQuestions.csv"):
    # Data to write
    # header = ["preamble", "question", "answer", "subject"]

    subject_parts = subject.split()
    main_subject = subject_parts[0] if len(subject_parts) > 0 else ""
    topic = " ".join(subject_parts[1:]) if len(subject_parts) > 1 else ""

    new_row = [preamble, question, answer, main_subject, topic]

    # Appending to a CSV file
    with open(path, mode='a', newline='') as file:
        csv_writer = csv.writer(file)
        csv_writer.writerow(new_row)

# Example usage
# write_to_csv(preamble='preamble', question='question', answer='answer', subject='subject topic')

# %%
# @title Run from here

prompts = [
    ("No", "Chemistry Solubility", "1") for x in range(150) # of course, this changes as we go through various topics in the various subjects. we discovered that this gives way better results than just naming it "Chemistry" or "Physics"
]

output_array = []

def gen_10questions(has_preamble, subject, question_type):
    preamble = ""
    question = ""
    answer = ""
    subject = ""

    promptOne = f"Has Preamble: {has_preamble}\nSubject: {subject}\nQuestion Type: {question_type}"

    FastLanguageModel.for_inference(model)
    inputs = tokenizer(
        [
            question_synth_prompt.format(
                f""" Please generate high quality real-world application questions in {prompts[0][1]} for the National Science and Math Quiz. do your OUTMOST best to make the questions as complex as possible.
                The questions can be application questions that have themes in any field.
                The questions must be very complex to the highest standard of university level students.
                Also, provide an answer to each question. It is very imiportant to provide an answer to every question!
                But do not provide any explanations for the answers whatsoever. Unless the question is an explanation question.
                And explanation questions must be real-life application questions
                """, # instruction
                promptOne, # input
                "", # output - leave this blank for generation!
            )
        ], return_tensors="pt").to("cuda")

    from transformers import TextStreamer
    text_streamer = TextStreamer(tokenizer)
    outputs = model.generate(**inputs, streamer=text_streamer, max_new_tokens=2048)
    output_array.append(tokenizer.batch_decode(outputs))

    # Combine all strings in the list into one string
    combined_text = ''.join(content[-1] for content in output_array)

    # Extract information from the combined text
    results = extract_info(combined_text)

    # Check if results contain data before accessing
    if results:
        for result in results:
            # Print or handle each result individually
            # preamble = result.get('preamble', "")
            # question = result.get('question', "")
            # answer = result.get('answer', "")
            # subject = result.get('subject', "")

            preamble = result['preamble']
            question = result['question']
            answer = result['answer']
            subject = result['subject']

        write_to_csv(preamble=preamble, question=question, answer=answer, subject=subject)
        print("written to csv...")
    else:
        print("No results to process")

for x in prompts:
    gen_10questions(x[0], x[1], x[2])

# %%
# @title Clean up csv

import pandas as pd
import re

# Read the CSV file into a DataFrame
df = pd.read_csv('generatedQuestions.csv')

# Function to extract the subject from the preamble
def extract_subject(preamble):
    if isinstance(preamble, str):
        match = re.search(r'Subject:\s*(\w+)', preamble)
        if match:
            return match.group(1)
    return None

# Function to clean the preamble column
def clean_preamble(preamble):
    if isinstance(preamble, str):
        if preamble.startswith("None"):
            return "None"
        else:
            match = re.search(r'(None)? Subject:.*', preamble)
            if match:
                preamble_cleaned = preamble.split(" Subject:")[0].strip()
                return preamble_cleaned if preamble_cleaned else "None"
    return preamble

# Convert the preamble column to strings
df['preamble'] = df['preamble'].astype(str)

# Apply the function to extract the subject
df['subject'] = df['preamble'].apply(extract_subject)

# Apply the function to clean the preamble
df['preamble'] = df['preamble'].apply(clean_preamble)

# Save the updated DataFrame to a new CSV file
df.to_csv('combinedgenquestions.csv', index=False)

print("Operation completed successfully ...")

# %%
# @title Convert csv to db file

import csv
import sqlite3

# Establish a connection to a new or existing SQLite database
connection = sqlite3.connect('data.db')
cursor = connection.cursor()

# Create a new table to store the data
cursor.execute('''
CREATE TABLE IF NOT EXISTS questions (
    has_preamble TEXT,
    preamble_text TEXT,
    question TEXT,
    answer TEXT,
    subject TEXT,
    question_type TEXT,
    form TEXT,
    difficulty TEXT,
    subject_topic TEXT
)
''')

track=0
# Open the CSV file and read data
with open('combinedgenquestions.csv', newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        track=track+1
        cursor.execute('''
        INSERT INTO questions (has_preamble, preamble_text, question, answer, subject,
                               question_type, form, difficulty, subject_topic)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)''',
        (row['has_preamble'], row['preamble_text'], row['question'], row['answer'],
         row['subject'], row['question_type'], row['form'], row['difficulty'], row['subject_topic']))
        print(track)

# Commit the changes to the database
connection.commit()
# Close the connection
connection.close()
